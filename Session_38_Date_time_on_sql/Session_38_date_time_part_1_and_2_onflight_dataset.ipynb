# %%
import pandas as pd

# %%
flights = pd.read_csv("flights.csv")
flights
# Out:
#        index            Airline Date_of_Journey    Source Destination  \
# 0          0        Jet Airways      2019-01-03  Banglore   New Delhi
# 1          1           SpiceJet      2019-01-03  Banglore   New Delhi
# 2          2        Jet Airways      2019-01-03  Banglore   New Delhi
# 3          3          Air India      2019-01-03  Banglore   New Delhi
# 4          4        Jet Airways      2019-01-03  Banglore   New Delhi
# ...      ...                ...             ...       ...         ...
# 10678  10678  Multiple carriers      2019-12-06     Delhi      Cochin
# 10679  10679             IndiGo      2019-12-06   Kolkata    Banglore
# 10680  10680        Jet Airways      2019-12-06     Delhi      Cochin
# 10681  10681           Air Asia      2019-12-06   Kolkata    Banglore
# 10682  10682        Jet Airways      2019-12-06     Delhi      Cochin
#
#       Dep_Time Duration Total_Stops              Additional_Info  Price
# ...

# %%
import pymysql
con = pymysql.connect(host = "localhost",password = 'campusx',user = 'root',database ='flight_38')

# %%
from sqlalchemy import create_engine
import sqlalchemy

# %%
engine = create_engine("mysql+pymysql://root:campusx@localhost/flight_38")
flights.to_sql("flights", con=engine)
# Out:
# 10683

# %%
flights_v1 = pd.read_csv("flights_v1.csv")
flights_v1
# Out:
#       level_0;"index";"Airline";"Date_of_Journey";"Source";"Destination";"Dep_Time";"Duration";"Total_Stops";"Additional_Info";"Price";"departure";"duration_mins";"arrival"
# 0      0;0;"Jet Airways";"2019-01-03";"Banglore";"New...
# 1      1;1;"SpiceJet";"2019-01-03";"Banglore";"New De...
# 2      2;2;"Jet Airways";"2019-01-03";"Banglore";"New...
# 3      3;3;"Air India";"2019-01-03";"Banglore";"New D...
# 4      4;4;"Jet Airways";"2019-01-03";"Banglore";"New...
# ...                                                  ...
# 10678  10678;10678;"Multiple carriers";"2019-12-06";"...
# 10679  10679;10679;"IndiGo";"2019-12-06";"Kolkata";"B...
# 10680  10680;10680;"Jet Airways";"2019-12-06";"Delhi"...
# 10681  10681;10681;"Air Asia";"2019-12-06";"Kolkata";...
# 10682  10682;10682;"Jet Airways";"2019-12-06";"Delhi"...
#
# [10683 rows x 1 columns]
