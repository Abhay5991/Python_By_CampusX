# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Insurance Dataset : https://docs.google.com/spreadsheets/d/1dAc3E4U-gBzihJ6HLM2kYVDAqQthdReg20zwwaplTW8/edit?usp=share_link

# %%
insurance =pd.read_csv("insurance.csv")
insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
# ### Q-1: What is the probability distribution of age in the insurance dataset?
#
# -- Find out using the KDE method

# %%
# code here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(data=insurance, x='age')
plt.show()

# %% [markdown]
# ### Q-2: What is the probability of a patient having a BMI greater than 30?

# %%
bmi_greater_than_30 =insurance[insurance['bmi'] > 30]
bmi_greater_than_30
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# 5         5          6   NaN    male  34.4             96      Yes         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
len(bmi_greater_than_30)
# Out:
# 699

# %%
len(insurance)
# Out:
# 1340

# %%
len(bmi_greater_than_30) / len(insurance)
# Out:
# 0.5216417910447761

# %%
# answer here
bmi_greater_than_30 = insurance[insurance['bmi'] > 30]
prob_bmi_greater_than_30 = len(bmi_greater_than_30) / len(insurance)
print(prob_bmi_greater_than_30)
# Out:
# 0.5216417910447761

# %%
insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
# ### Q-3: Plot distribution plot of claim for Smoker and non smoker. What changes you see in the plot?

# %%
sns.displot(data=insurance, x='claim', hue='smoker', kde=True)

# %% [markdown]
# - The distribution of claim for smokers is shifted towards higher values compared to non-smokers. This means that on average, smokers tend to have higher insurance claims than non-smokers.
#
# - Additionally, we can see that the shape of the distribution for smokers is more spread out and has a longer tail compared to non-smokers. This indicates that the variability of claim amounts is higher for smokers.
#
# - Overall, the distribution plot highlights the differences in the distribution of claim amounts between smokers and non-smokers, which can provide insights into the factors that affect insurance claims in the dataset.

# %% [markdown]
# ### Q-4: Plot the 2D probability density plot of claim and age in the insurance dataset?

# %%
# code here
sns.kdeplot(data=insurance, x='age', y='claim', fill=True, cmap='crest', levels=20, thresh=0.05)
# Out:
# <AxesSubplot:xlabel='age', ylabel='claim'>

# %% [markdown]
# ### Q-5: How does the disribution of claim changes for different region? Plot density plot and note down the observations

# %%
# code here
sns.kdeplot(data=insurance, x='claim', hue='region', fill=True, alpha=0.4, palette='bright')
# Out:
# <AxesSubplot:xlabel='claim', ylabel='Density'>

# %% [markdown]
# - Observations:
#
# - The density plot shows the probability distribution of claims for each region.
# - The southeast region has the highest density of claims, indicating that patients from this region are more likely to make higher insurance claims.
# - The northwest region has the lowest density of claims, indicating that patients from this region are less likely to make higher insurance claims.

# %% [markdown]
# ### Q6: Plot PDF and CDF of claim in insurance data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(12, 4))

# Plot PDF
plt.subplot(1, 2, 1)
sns.histplot(data=insurance, x="claim", kde=True, stat="density")
plt.title("PDF of Claim")

# Plot CDF
plt.subplot(1, 2, 2)
sns.histplot(data=insurance, x="claim", kde=True, cumulative=True, stat="density")
plt.title("CDF of Claim")

# Show plot
plt.show()

# %% [markdown]
# ### Q-7: Given a probability density function f(x) = 2x for 0 <= x <= 1 and f(x) = 0 otherwise, compute the cumulative distribution function F(x) and plot it. Use this to find the probability that X is greater than 0.5.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the probability density function
def pdf(x):
    return 2*x if 0 <= x <= 1 else 0

# Define the cumulative distribution function
def cdf(x):
    if x <= 0:
        return 0
    elif x >= 1:
        return 1
    else:
        return x**2

# Plot the PDF and CDF
x = np.linspace(-0.2, 1.2, 500)
y_pdf = [pdf(xi) for xi in x]
y_cdf = [cdf(xi) for xi in x]
plt.plot(x, y_pdf, label='PDF')
plt.plot(x, y_cdf, label='CDF')
plt.legend()

# Find the probability that X is greater than 0.5
prob = 1 - cdf(0.5)
print('Probability that X is greater than 0.5:', prob)
# Out:
# Probability that X is greater than 0.5: 0.75

# %% [raw]
# To calculate the cumulative distribution function (CDF) from a probability density function (PDF), we integrate the PDF from negative infinity up to the value of interest. In other words, the CDF at a particular value x is the area under the PDF curve from negative infinity up to x.
#
# For example, in the given PDF f(x) = 2x for 0 <= x <= 1 and f(x) = 0 otherwise, we can calculate the CDF F(x) as follows:
#
# For x < 0, F(x) = 0, since the PDF is 0 for negative x values.
# For 0 <= x <= 1, F(x) = ∫[0,x] 2t dt = [t^2]_[0,x] = x^2
# For x > 1, F(x) = 1, since the PDF is 0 for x values greater than 1.
#
# So the CDF is given by:
#
# F(x) = { 0 for x < 0
# x^2 for 0 <= x <= 1
# 1 for x > 1 }
#
# To find the probability that X is greater than 0.5, we can simply evaluate the CDF at 0.5 and subtract the result from 1:
#
# P(X > 0.5) = 1 - F(0.5) = 1 - (0.5)^2 = 0.75
#
# Therefore, the probability that X is greater than 0.5 is 0.75 or 75%.

# %% [markdown]
# ### Q-8: In a manufacturing process, the thickness of a certain material is known to be normally distributed with a mean of 1.2 mm and a standard deviation of 0.05 mm. What is the probability density function of the thickness? Plot the PDF and use it to compute the probability that the thickness is between 1.1 mm and 1.3 mm.

# %%
# answer here
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the mean and standard deviation of the thickness distribution
mu = 1.2
sigma = 0.05

# Define the range of thickness values to plot the PDF
x = np.linspace(1.0, 1.4, 100)

# Compute the PDF of the thickness distribution
pdf = norm.pdf(x, mu, sigma)

# Plot the PDF
plt.plot(x, pdf)
plt.xlabel('Thickness (mm)')
plt.ylabel('Probability density')
plt.title('PDF of thickness distribution')

# Compute the probability that the thickness is between 1.1 mm and 1.3 mm
prob = norm.cdf(1.3, mu, sigma) - norm.cdf(1.1, mu, sigma)
print('Probability that the thickness is between 1.1 mm and 1.3 mm:', prob)
# Out:
# Probability that the thickness is between 1.1 mm and 1.3 mm: 0.9544997361036416

# %% [markdown]
# ### Q-9 : A data scientist is investigating the distribution of customer ages in a retail store. She collects a sample of 100 ages and estimates the probability density function using kernel density estimation. What bandwidth should she choose to obtain the best estimate?

# %%
# answer here
import numpy as np
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt

# Generate some sample data
ages = np.random.normal(30, 10, size=100)

# Estimate the kernel density function with different bandwidths
bandwidths = np.arange(0.5, 5, 0.1)
kdes = [gaussian_kde(ages, bw_method=bw) for bw in bandwidths]

# Compute the log-likelihood of the data for each bandwidth
log_likelihoods = [kde.logpdf(ages).sum() for kde in kdes]

# Choose the bandwidth with the highest log-likelihood
best_bandwidth = bandwidths[np.argmax(log_likelihoods)]

# Plot the estimated density function with the best bandwidth
kde = gaussian_kde(ages, bw_method=best_bandwidth)
xs = np.linspace(0, 60, 100)
plt.plot(xs, kde(xs), label='KDE estimate (bw={:.2f})'.format(best_bandwidth))
plt.hist(ages, density=True, alpha=0.5, label='Sample data')
plt.legend()
plt.show()

# %% [raw]
# This code generates a sample of 100 ages drawn from a normal distribution with mean 30 and standard deviation 10. It then estimates the kernel density function using the 'gaussian_kde' function from the 'scipy.stats' library, with bandwidths ranging from 0.5 to 5 in steps of 0.1. The log-likelihood of the data is computed for each bandwidth, and the bandwidth with the highest log-likelihood is chosen as the best estimate. Finally, the estimated density function with the best bandwidth is plotted along with a histogram of the sample data.

# %% [raw]
# The choice of bandwidth in kernel density estimation can have a significant impact on the resulting estimate. A larger bandwidth will result in a smoother estimate, but may oversmooth the data and miss important features, while a smaller bandwidth will be more sensitive to noise and may result in a more jagged estimate.
#
# There are several methods for choosing the optimal bandwidth for kernel density estimation, including the rule-of-thumb method, the cross-validation method, and the maximum likelihood method.
#
# The rule-of-thumb method suggests that the optimal bandwidth h can be estimated as:
#
# h = 1.06 * σ * n^(-1/5)
#
# where σ is the standard deviation of the data and n is the sample size.
#
# In this case, we have a sample size of n=100 and a standard deviation of σ=unknown. Therefore, we cannot determine the optimal bandwidth using the rule-of-thumb method without additional information.
#
# The cross-validation method involves splitting the data into training and testing sets, and choosing the bandwidth that minimizes the mean-squared error between the estimated density and the true density on the testing set.
#
# The maximum likelihood method involves choosing the bandwidth that maximizes the likelihood of the data under the estimated density.
#
# Therefore, to determine the optimal bandwidth for this particular case, the data scientist could use the cross-validation or maximum likelihood method, or seek additional information about the standard deviation of the data to apply the rule-of-thumb method.
